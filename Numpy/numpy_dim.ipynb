# %%
import numpy as np
from PIL import Image

# %%
import numpy as np
arr4d = np.array([[[[1,2,3],[4,5,6]],
                 [[10,20,30],[40,50,60]]],
                 [[[100,200,300],[400,500,600]],
                 [[1000,2000,3000],[4000,5000,6000]]]])
arr4d
# Out:
# array([[[[   1,    2,    3],
#          [   4,    5,    6]],
#
#         [[  10,   20,   30],
#          [  40,   50,   60]]],
#
#
#        [[[ 100,  200,  300],
#          [ 400,  500,  600]],
#
#         [[1000, 2000, 3000],
#          [4000, 5000, 6000]]]])

# %%
print(arr4d.sum(axis=0), "\n")
print("-"*20)
print(arr4d.sum(axis=1), "\n")
print("-"*20)
print(arr4d.sum(axis=2), "\n")
print("-"*20)
print(arr4d.sum(axis=3), "\n")
# Out:
# [[[ 101  202  303]
#   [ 404  505  606]]
#
#  [[1010 2020 3030]
#   [4040 5050 6060]]]
#
# --------------------
# [[[  11   22   33]
#   [  44   55   66]]
#
#  [[1100 2200 3300]
#   [4400 5500 6600]]]
#
# --------------------
# [[[   5    7    9]
#   [  50   70   90]]
#
#  [[ 500  700  900]
#   [5000 7000 9000]]]
#
# --------------------
# [[[    6    15]
#   [   60   150]]
#
#  [[  600  1500]
#   [ 6000 15000]]]

# %%
img = Image.open('/users/jjong/desktop/vscode/AI_academy/shape.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=700x479>

# %%
img2 = Image.open('/users/jjong/desktop/vscode/AI_academy/cube.png')
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x487>
