# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df1 = pd.read_csv('./mct31_data/mct31_5월3주차.csv')
df2 = pd.read_csv('./mct31_data/mct31_5월4주차.csv')
df3 = pd.read_csv('./mct31_data/mct31_6월1주차.csv')
df4 = pd.read_csv('./mct31_data/mct31_6월2주차.csv')
df4 = pd.read_csv('./mct31_data/mct31_6월3주차.csv')
df5 = pd.read_csv('./mct31_data/mct31_6월4주차.csv')
df6 = pd.read_csv('./mct31_data/mct31_6월5주차.csv')
df7 = pd.read_csv('./mct31_data/mct31_7월1주차.csv')
df8 = pd.read_csv('./mct31_data/mct31_7월2주차.csv')
df9 = pd.read_csv('./mct31_data/mct31_7월3주차.csv')
df10 = pd.read_csv('./mct31_data/mct31_7월4주차.csv')
# df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10], axis=0).reset_index(drop=True)

# %%
df1.set_index('GDatetime', inplace=True)

# %%
df1.iloc[:,14:].plot(figsize=(16,16))
# Out:
# <Axes: xlabel='GDatetime'>

# %%
df1
# Out:
#                         F_RunState  F_OperationTime  F_CuttingTime  \
# GDatetime
# 2023-05-18 14:38:24.795        작업중         431109.0       170253.0
# 2023-05-18 14:38:25.530        작업중         431109.0       170253.0
# 2023-05-18 14:38:26.531        작업중         431110.0       170254.0
# 2023-05-18 14:38:27.531        작업중         431112.0       170255.0
# 2023-05-18 14:38:28.531        작업중         431113.0       170256.0
# ...                            ...              ...            ...
# 2023-05-20 07:00:32.004       STOP         673212.0       322431.0
# 2023-05-20 07:00:32.973       STOP         673212.0       322431.0
# 2023-05-20 07:00:33.973       STOP         673212.0       322431.0
# 2023-05-20 07:00:34.973       STOP         673212.0       322431.0
# 2023-05-20 07:00:35.974       STOP         673212.0       322431.0
#
#                          F_CycleTime  F_SpindleRPM1  F_SpindleTroq1  \
# GDatetime
# 2023-05-18 14:38:24.795         1858         2133.0             7.0
# ...

# %%
data = pd.read_csv('mct31_merge.csv')
data
# Out:
#          Unnamed: 0                GDatetime F_RunState  F_OperationTime  \
# 0                 0  2023-05-18 14:38:24.795        작업중         431109.0
# 1                 1  2023-05-18 14:38:25.530        작업중         431109.0
# 2                 2  2023-05-18 14:38:26.531        작업중         431110.0
# 3                 3  2023-05-18 14:38:27.531        작업중         431112.0
# 4                 4  2023-05-18 14:38:28.531        작업중         431113.0
# ...             ...                      ...        ...              ...
# 4224843     4224843  2023-07-29 07:45:15.174        NaN              NaN
# 4224844     4224844  2023-07-29 07:45:16.179        NaN              NaN
# 4224845     4224845  2023-07-29 07:45:17.195        NaN              NaN
# 4224846     4224846  2023-07-29 07:45:18.211        NaN              NaN
# 4224847     4224847  2023-07-29 07:45:19.221        NaN              NaN
#
#          F_CuttingTime  F_CycleTime  F_SpindleRPM1  F_SpindleTroq1  \
# ...

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.iloc[:, :-5]
# Out:
#                        GDatetime F_RunState  F_OperationTime  F_CuttingTime  \
# 0        2023-05-18 14:38:24.795        작업중         431109.0       170253.0
# 1        2023-05-18 14:38:25.530        작업중         431109.0       170253.0
# 2        2023-05-18 14:38:26.531        작업중         431110.0       170254.0
# 3        2023-05-18 14:38:27.531        작업중         431112.0       170255.0
# 4        2023-05-18 14:38:28.531        작업중         431113.0       170256.0
# ...                          ...        ...              ...            ...
# 4224843  2023-07-29 07:45:15.174        NaN              NaN            NaN
# 4224844  2023-07-29 07:45:16.179        NaN              NaN            NaN
# 4224845  2023-07-29 07:45:17.195        NaN              NaN            NaN
# 4224846  2023-07-29 07:45:18.211        NaN              NaN            NaN
# 4224847  2023-07-29 07:45:19.221        NaN              NaN            NaN
#
# ...

# %%
data.iloc[:, :-6].to_csv('mct31_merge_2.csv')

# %%
df = pd.read_csv('mct31_merge_2.csv')

# %%
df = df.drop(['F_RunState', 'F_OperationTime', 'F_CuttingTime', 'F_ToolNum', 'Unnamed: 0'], axis=1)
df['GDatetime'] = pd.to_datetime(df['GDatetime'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4224848 entries, 0 to 4224847
# Data columns (total 22 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   GDatetime            datetime64[ns]
#  1   F_CycleTime          int64
#  2   F_SpindleRPM1        float64
#  3   F_SpindleTroq1       float64
#  4   F_SpindleGearRatio1  float64
#  5   F_AbsoluteX          float64
#  6   F_AbsoluteY          float64
#  7   F_AbsoluteZ          float64
#  8   F_DistanceX          float64
#  9   F_DistanceY          float64
#  10  F_DistanceZ          float64
#  11  G_ADC1               float64
#  12  G_ADC2               float64
#  13  G_ADC3               float64
#  14  G_ADC4               float64
#  15  G_MV                 float64
#  16  G_MA                 float64
#  17  G_MActP              float64
#  18  G_MRActP             float64
#  19  G_MPF                float64
#  20  G_MFeq               float64
#  21  G_MTemp              float64
# ...

# %%
df.set_index('GDatetime', drop=True, inplace=True)
df
# Out:
#                          F_CycleTime  F_SpindleRPM1  F_SpindleTroq1  \
# GDatetime
# 2023-05-18 14:38:24.795         1858         2133.0             7.0
# 2023-05-18 14:38:25.530         1858         2133.0             7.0
# 2023-05-18 14:38:26.531         1859         2133.0             7.0
# 2023-05-18 14:38:27.531         1901         2132.0             4.0
# 2023-05-18 14:38:28.531         1902         2133.0             7.0
# ...                              ...            ...             ...
# 2023-07-29 07:45:15.174            0            0.0             0.0
# 2023-07-29 07:45:16.179            0            0.0             0.0
# 2023-07-29 07:45:17.195            0            0.0             0.0
# 2023-07-29 07:45:18.211            0            0.0             0.0
# 2023-07-29 07:45:19.221            0            0.0             0.0
#
#                          F_SpindleGearRatio1  F_AbsoluteX  F_AbsoluteY  \
# GDatetime
# ...

# %%
plt.figure(figsize=(16,16))
sns.heatmap(df.corr(), annot=True, fmt='.2f')
plt.show()

# %%
count = 0
for col in df.columns:
    if df[col].nunique() == 1 and df[col].unique()[0] == 0:
        print(col, 0)
    else:
        count += 1
        print(col, count)
# Out:
# Unnamed: 0 1
# GDatetime 2
# F_RunState 3
# F_OperationTime 4
# F_CuttingTime 5
# F_CycleTime 6
# F_SpindleRPM1 7
# F_SpindleTroq1 8
# F_SpindleGearRatio1 9
# F_ToolNum 10
# F_AbsoluteX 11
# F_AbsoluteY 12
# F_AbsoluteZ 13
# F_DistanceX 14
# F_DistanceY 15
# F_DistanceZ 16
# G_ADC1 17
# G_ADC2 18
# G_ADC3 19
# G_ADC4 20
# G_MV 21
# G_MA 22
# G_MActP 23
# G_MRActP 24
# G_MPF 25
# G_MFeq 26
# G_MTemp 27
