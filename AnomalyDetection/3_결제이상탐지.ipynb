# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - train 에 이상없는 것들만
# - 특성 29개

# %%
data = pd.read_csv('creditcard.csv')
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
data.drop(['Time'], axis=1, inplace=True)

# %%
data
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# 0       0.239599  0.098698  0.363787  0.090794  ... -0.018307  0.277838
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.247998  0.771679
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274
# 4       0.592941 -0.270533  0.817739  0.753074  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.213454  0.111864
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.214205  0.924384
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.232045  0.578229
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.265245  0.800049
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

normal = data[data['Class'] == 0].drop('Class', axis=1)
abnormal = data[data['Class'] == 1].drop('Class', axis=1)

# %%
data['Class'].value_counts(normalize=True)
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# X_train, X_normal_test = train_test_split(normal, 0.02)
X_train = normal.values[:283823]
X_normal_test = normal.values[283823:]
X_anormal_test = abnormal.values

sc = StandardScaler()
X_train_std = sc.fit_transform(X_train)
X_normal_test_std = sc.transform(X_normal_test)
X_anormal_test_std = sc.transform(X_anormal_test)

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Model

n_features = 29
latent_dim = 10

# 인코더
enc_inputs = layers.Input(shape=(n_features,))
x = layers.Dense(20, activation='relu')(enc_inputs)
enc_outputs = layers.Dense(latent_dim, activation='relu')(x) # Latent vector

encoder = Model(inputs=enc_inputs, outputs=enc_outputs)

# 디코더
dec_inputs = layers.Input(shape=(latent_dim,)) # Latent vector
x = layers.Dense(20, activation='relu')(dec_inputs)
dec_outputs = layers.Dense(n_features, activation='linear')(x) # 데이터를 보고 거기에 맞춰서 활성화 함수 사용 

decoder = Model(inputs=dec_inputs, outputs=dec_outputs)

# 오토인코더
inputs = layers.Input(shape=(n_features,))
latent = encoder(inputs)
outputs = decoder(latent)

AE = Model(inputs=inputs, outputs=outputs)
AE.compile(optimizer='adam', loss='mse') # 오차 구하는 것 중에 미분이 잘 되는 것 mse
AE.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 29)]              0
#
#  model_3 (Functional)        (None, 10)                810
#
#  model_4 (Functional)        (None, 29)                829
#
# =================================================================
# Total params: 1,639
# Trainable params: 1,639
# Non-trainable params: 0
# _________________________________________________________________

# %%
AE.fit(X_train_std, X_train_std, validation_split=0.2, batch_size=128, epochs=20) # 압축 후 복원하기 때문에, 자신과 비교
# Out:
# Epoch 1/20
# 1774/1774 [==============================] - 3s 1ms/step - loss: 0.5864 - val_loss: 0.4687
# Epoch 2/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.4070 - val_loss: 0.4135
# Epoch 3/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.3732 - val_loss: 0.3946
# Epoch 4/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.3563 - val_loss: 0.3818
# Epoch 5/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.3403 - val_loss: 0.3667
# Epoch 6/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.3237 - val_loss: 0.3516
# Epoch 7/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.3095 - val_loss: 0.3388
# Epoch 8/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.3016 - val_loss: 0.3458
# Epoch 9/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2975 - val_loss: 0.3363
# Epoch 10/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2947 - val_loss: 0.3358
# Epoch 11/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2932 - val_loss: 0.3352
# Epoch 12/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2912 - val_loss: 0.3347
# Epoch 13/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2902 - val_loss: 0.3355
# Epoch 14/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2892 - val_loss: 0.3372
# Epoch 15/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2879 - val_loss: 0.3308
# Epoch 16/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2872 - val_loss: 0.3327
# Epoch 17/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2862 - val_loss: 0.3278
# Epoch 18/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2856 - val_loss: 0.3256
# Epoch 19/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2845 - val_loss: 0.3321
# Epoch 20/20
# 1774/1774 [==============================] - 2s 1ms/step - loss: 0.2842 - val_loss: 0.3242

# %%
p_normal = AE.predict(X_normal_test_std)
p_anormal = AE.predict(X_anormal_test_std)
# Out:
# 16/16 [==============================] - 0s 1ms/step
# 16/16 [==============================] - 0s 1ms/step

# %%
def reconstruction_error(x, p):
    return np.mean(np.abs(x - p), axis=1)

re_normal = reconstruction_error(X_normal_test_std, p_normal)
re_anormal = reconstruction_error(X_anormal_test_std, p_anormal)

# %%
re_all = np.concatenate([re_normal, re_anormal])
label_all = np.concatenate([np.zeros_like(re_normal), np.ones_like(re_anormal)])

# %%
plt.figure()
sns.histplot(x=re_all, bins=50, hue=label_all, kde=True)
plt.show()

# %%
from sklearn.metrics import f1_score, recall_score, precision_score, roc_curve

recall = []
precision = []
f1 = []

thresholds = np.arange(0, 1, 0.01)
for thres in thresholds:
    results = re_all > thres
    recall.append(recall_score(label_all, results))
    precision.append(precision_score(label_all, results))
    f1.append(f1_score(label_all, results))

plt.figure()
plt.plot(thresholds, recall, label='recall')
plt.plot(thresholds, precision, label='precision')
plt.plot(thresholds, f1, label='f1')

plt.axvline(thresholds[np.argmax(f1)], color='red', linestyle='--')
plt.text(thresholds[np.argmax(f1)], 1.05, 'threshold = {}\nf1 = {:.4f}'.format(thresholds[np.argmax(f1)], np.max(f1)),
         color='red', horizontalalignment='center')

plt.legend()
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(label_all, re_all)
plt.figure()
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--', color='r')
plt.show()

# %%
def mod_z(f): # 2 이상이면 이상치
    med_f = np.median(f)
    med_abs_dev = np.median((np.abs(f - med_f)))
    mod_z = 0.7413 * ((f - med_f) / med_abs_dev)
    return np.abs(mod_z)

mod_z = mod_z(re_all)
sns.histplot(x=mod_z, kde=True, bins=50, hue=label_all)
plt.show()
